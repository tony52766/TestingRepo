# %%
import psycopg2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import uuid
import random
from faker import Faker

# %%
Address = pd.read_csv('/Users/tonyjason/Documents/DMQL Project/Address.csv')

# %%
Address.head()
# Out:
#    address_id               address  address2  district  city_id  postal_code  \
# 0           1     47 MySakila Drive       NaN   Alberta      300          NaN
# 1           2    28 MySQL Boulevard       NaN       QLD      576          NaN
# 2           3     23 Workhaven Lane       NaN   Alberta      300          NaN
# 3           4  1411 Lillydale Drive       NaN       QLD      576          NaN
# 4           5        1913 Hanoi Way       NaN  Nagasaki      463      35200.0
#
#           phone          last_update
# 0           NaN  2006-02-15 09:45:30
# 1           NaN  2006-02-15 09:45:30
# 2  1.403334e+10  2006-02-15 09:45:30
# 3  6.172236e+09  2006-02-15 09:45:30
# 4  2.830338e+10  2006-02-15 09:45:30

# %%
#Establishing the connection
conn = psycopg2.connect(
   database="Testing", user='postgres', password='Tony@8669', host='localhost', port= '5432'
)
#Setting auto commit false
conn.autocommit = True

#Creating a cursor object using the cursor() method
cursor = conn.cursor()


#for i in range(len(Address)):
#    cursor.execute('''INSERT INTO ADDRESS(address_id, address, district, city_id, postal_code, phone_num) VALUES (Address.loc[i,'address_id'], Address.loc[i,'address'], Address.loc[i,'district'], Address.loc[i,'city_id'], Address.loc[i,'postal_code'],Address.loc[i,'phone_num'])''')

cursor.execute('''INSERT INTO ADDRESS(address_id, address, district, city_id, postal_code, phone_num) VALUES ('''Address.loc[i,'address_id']',' Address.loc[i,'address']',' Address.loc[i,'district']',' Address.loc[i,'city_id']',' Address.loc[i,'postal_code']','Address.loc[i,'phone_num']')')

# Preparing SQL queries to INSERT a record into the database.


# Commit your changes in the database
conn.commit()
print("Records inserted........")

# Closing the connection
conn.close()
# Out:
#   Input In [19]
#     cursor.execute('''INSERT INTO ADDRESS(address_id, address, district, city_id, postal_code, phone_num) VALUES ('''Address.loc[i,'address_id']',' Address.loc[i,'address']',' Address.loc[i,'district']',' Address.loc[i,'city_id']',' Address.loc[i,'postal_code']','Address.loc[i,'phone_num']')')
#                                                                                                                      ^
# SyntaxError: invalid syntax

# %%
for i in range(len(Address)):
    print("Address Id:%(Address.loc[i,'address_id'])s", Address.loc[i,'address_id'])
# Out:
# Address Id:%(Address.loc[i,'address_id'])s 1
# Address Id:%(Address.loc[i,'address_id'])s 2
# Address Id:%(Address.loc[i,'address_id'])s 3
# Address Id:%(Address.loc[i,'address_id'])s 4
# Address Id:%(Address.loc[i,'address_id'])s 5
# Address Id:%(Address.loc[i,'address_id'])s 6
# Address Id:%(Address.loc[i,'address_id'])s 7
# Address Id:%(Address.loc[i,'address_id'])s 8
# Address Id:%(Address.loc[i,'address_id'])s 9
# Address Id:%(Address.loc[i,'address_id'])s 10
# Address Id:%(Address.loc[i,'address_id'])s 11
# Address Id:%(Address.loc[i,'address_id'])s 12
# Address Id:%(Address.loc[i,'address_id'])s 13
# Address Id:%(Address.loc[i,'address_id'])s 14
# Address Id:%(Address.loc[i,'address_id'])s 15
# Address Id:%(Address.loc[i,'address_id'])s 16
# Address Id:%(Address.loc[i,'address_id'])s 17
# Address Id:%(Address.loc[i,'address_id'])s 18
# Address Id:%(Address.loc[i,'address_id'])s 19
# Address Id:%(Address.loc[i,'address_id'])s 20
# Address Id:%(Address.loc[i,'address_id'])s 21
# ...

# %%
Address.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 Address.head()
#
# NameError: name 'Address' is not defined

# %%
Address.drop(['address2','last_update'], axis=1, inplace=True)
Address.head()
# Out:
#    address_id               address  district  city_id  postal_code  \
# 0           1     47 MySakila Drive   Alberta      300          NaN
# 1           2    28 MySQL Boulevard       QLD      576          NaN
# 2           3     23 Workhaven Lane   Alberta      300          NaN
# 3           4  1411 Lillydale Drive       QLD      576          NaN
# 4           5        1913 Hanoi Way  Nagasaki      463      35200.0
#
#           phone
# 0           NaN
# 1           NaN
# 2  1.403334e+10
# 3  6.172236e+09
# 4  2.830338e+10

# %%
Address.rename(columns = {'phone':'phone_num'}, inplace = True)
Address.head()
# Out:
#    address_id               address  district  city_id  postal_code  \
# 0           1     47 MySakila Drive   Alberta      300          NaN
# 1           2    28 MySQL Boulevard       QLD      576          NaN
# 2           3     23 Workhaven Lane   Alberta      300          NaN
# 3           4  1411 Lillydale Drive       QLD      576          NaN
# 4           5        1913 Hanoi Way  Nagasaki      463      35200.0
#
#       phone_num
# 0           NaN
# 1           NaN
# 2  1.403334e+10
# 3  6.172236e+09
# 4  2.830338e+10

# %%
Address.to_csv('AddressNew.csv')

# %%
import psycopg2 
  

conn = psycopg2.connect(database="Testing", 

                        user='postgres', password='Tony@8669',  

                        host='localhost', port='5432'
) 

  

conn.autocommit = True

cursor = conn.cursor() 

  

  



  

  

  

sql2 = '''\COPY address(address_id,address,district,city_id,postal_code,phone_num) 
FROM '/private/var/folders/16/84_yc3ks3_56wmdv0rgc67b40000gn/T/AddressNew.csv' 
DELIMITER ',' 
CSV HEADER;'''

  
cursor.execute(sql2) 

  

  
conn.commit() 
conn.close()
# Out:
# ---------------------------------------------------------------------------
# InsufficientPrivilege                     Traceback (most recent call last)
# Input In [15], in <cell line: 35>()
#      15 cursor = conn.cursor()
#      29 sql2 = '''COPY address(address_id,address,district,city_id,postal_code,phone_num)
#      30 FROM '/private/var/folders/16/84_yc3ks3_56wmdv0rgc67b40000gn/T/AddressNew.csv'
#      31 DELIMITER ','
#      32 CSV HEADER;'''
# ---> 35 cursor.execute(sql2)
#      40 conn.commit()
#      41 conn.close()
#
# InsufficientPrivilege: could not open file "/private/var/folders/16/84_yc3ks3_56wmdv0rgc67b40000gn/T/AddressNew.csv" for reading: Permission denied
# HINT:  COPY FROM instructs the PostgreSQL server process to read a file. You may want a client-side facility such as psql's \copy.

# %%
''#######sql = '''CREATE TABLE DETAILS(employee_id int NOT NULL,\ 
#employee_name char(20),\ 
#employee_email varchar(30), employee_salary float);'''


sql3 = '''select * from details;'''
cursor.execute(sql3) 

for i in cursor.fetchall(): 

    print(i)

# %%
AddressNew = pd.read_csv('/Users/tonyjason/Documents/DMQLProject/AddressNew.csv')

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine


conn_string = 'postgresql://postgres:Tony@8669@localhosthost/Testing'

db = create_engine(conn_string)
conn = db.connect()


# our dataframe
data = {'Name': ['Tom', 'dick', 'harry'],
		'Age': [22, 21, 24]}

# Create DataFrame


AddressNew.to_sql('AddressNew', con=conn, if_exists='replace',
		index=False)
conn = psycopg2.connect(conn_string
						)
conn.autocommit = True
cursor = conn.cursor()

sql1 = '''select * from data;'''
cursor.execute(sql1)
for i in cursor.fetchall():
	print(i)

# conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
AddressNew = AddressNew.reset_index(drop=True)

# %%
AddressNew.head()
# Out:
#    Unnamed: 0  address_id               address  district  city_id  \
# 0           0           1     47 MySakila Drive   Alberta      300
# 1           1           2    28 MySQL Boulevard       QLD      576
# 2           2           3     23 Workhaven Lane   Alberta      300
# 3           3           4  1411 Lillydale Drive       QLD      576
# 4           4           5        1913 Hanoi Way  Nagasaki      463
#
#    postal_code     phone_num
# 0          NaN           NaN
# 1          NaN           NaN
# 2          NaN  1.403334e+10
# 3          NaN  6.172236e+09
# 4      35200.0  2.830338e+10

# %%
Address.drop(['Unnamed: 0'], axis=1, inplace=True)
AddressNew = AddressNew.reset_index(drop=True)
AddressNew.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 Address.drop(['Unnamed: 0'], axis=1, inplace=True)
#       2 AddressNew = AddressNew.reset_index(drop=True)
#       3 AddressNew.head()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
for each in AddressNew:
    print(each)
# Out:
# Unnamed: 0
# address_id
# address
# district
# city_id
# postal_code
# phone_num

# %%
Address = pd.read_csv('/Users/tonyjason/Documents/DMQLProject/Address.csv')
Address.head()
# Out:
#    address_id               address  address2  district  city_id  postal_code  \
# 0           1     47 MySakila Drive       NaN   Alberta      300        14221
# 1           2    28 MySQL Boulevard       NaN       QLD      576        14221
# 2           3     23 Workhaven Lane       NaN   Alberta      300        14221
# 3           4  1411 Lillydale Drive       NaN       QLD      576        14221
# 4           5        1913 Hanoi Way       NaN  Nagasaki      463        35200
#
#           phone
# 0  1.234568e+10
# 1  1.234568e+10
# 2  1.403334e+10
# 3  6.172236e+09
# 4  2.830338e+10

# %%
Products = pd.read_csv('/Users/tonyjason/Documents/DMQLProject/Products.csv')
Products.head()
# Out:
#                          product_id                    category  \
# 0  0633d9fd9a3271730fae687f105c7a3a                      Juices
# 1  8687c5317c6629f89fe62e0233563246         Chocolates & Sweets
# 2  cf7eeba428641c14e43aa18ada1b5491     Household Care|Pet Food
# 3  9eb4d8359a3cbe7af6c5ac1c3149940e  Creams, Lotions, Skin Care
# 4  b84c9f6fc53da0c6921147063d894703                   Hair Care
#
#                                        product title  \
# 0             B Natural Dakshin Pink Guava  (750 ml)
# 1           Parle Melody Chocolaty Toffee  (195.5 g)
# 2     Whiskas Adult (+1 year) Fish 3 kg Dry Cat Food
# 3  Enchanteur Romantic Perfumed Body Lotion  (250...
# 4        Pantene Hair Fall Control Shampoo  (180 ml)
#
#                                  Product Description       Brand  \
# 0                                                NaN   B Natural
# 1                                                NaN       Parle
# ...

# %%
for i in range(len(Products)):
    print(type(Products.loc[i,'Stock Availibility']))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
Products['Stock Availibility'].unique()
# Out:
# array(['TRUE', 'SNSETFPYYWPSSGXG', 'FCWEVT77HYH48PVM', 'FALSE',
#        'HOLEXKKAHEHUKB4C', 'PEREUDFZ9XEQF2EY', 'BCRFEJWEZ5DGYQFT',
#        'NDFEXKKUNF8MHHPG', 'DPREN77Z4YHZSEWM', 'SCMF6UCWGAGGAJYR', nan,
#        'SMPD9FYFQFZT3GQZ', 'SRPEUHECXCKFFHTF', 'CAFF5WJ7KHFGZUA8',
#        'SATFDS2TPGJJFYKP', 'TLCE9MUFUHMKGEEY', 'NDFEXKKUGZRETTWG',
#        'SMPF6JX8JMVBWQSU', 'SRPEUDGGPWN7GWVG', 'HASEWXMT3WSZD2WH',
#        'IRPEU9J7YSRZYSEV', 'MLKF84SF7EYUAFNB', 'SNRFEQKAKFRF7BDE',
#        'SCMEUE5ZZWGFMFNZ', 'SCMFGGQMGDPG3Z2Q', 'SCMF6B8MJ3FRVHRZ',
#        'BWSEUD6BKJRQHP3J', 'SAMEUD5N5QK9YSW7', 'CHCFGZGFAZNEHHNE',
#        'LDTEVTERTZ9GXGKV', 'AIREZ9Z5G4NUGAPE', 'HASF5WMKTJTU3ADC',
#        'WFWF3KD94YHFGZKH', 'TPSEYJ4YGGPJA3FY', 'AIREU7Z7AXM9M4BZ',
#        'APCF8ZWY3WEZUXYH', 'CKBEUC5CAGPEZYGK', 'AIREUHAZUX2FFHNF',
#        'SPPEVCHVR2QN5GSP', 'KNREVJFY2ZGVFCGS', 'SPPFGHUPZPCNRZZA',
#        'CMFEUFQAKGN4PHKE', 'TPSDAG5YVRMEW5QS', 'CNDEUHBKQXRWHZAB',
# ...

# %%
Products.isnull()
# Out:
#        product_id  category  product title  Product Description  Brand  \
# 0           False     False          False                False  False
# 1           False     False          False                False  False
# 2           False     False          False                False  False
# 3           False     False          False                False  False
# 4           False     False          False                False  False
# ...           ...       ...            ...                  ...    ...
# 14998       False     False          False                False  False
# 14999       False     False          False                False  False
# 15000       False     False          False                False  False
# 15001       False     False          False                False  False
# 15002       False     False          False                False  False
#
#        Quantity Or Pack Size    Mrp  Price  Stock Availibility
# ...

# %%
# Out:
#                          product_id                    category  \
# 0  0633d9fd9a3271730fae687f105c7a3a                      Juices
# 1  8687c5317c6629f89fe62e0233563246         Chocolates & Sweets
# 2  cf7eeba428641c14e43aa18ada1b5491     Household Care|Pet Food
# 3  9eb4d8359a3cbe7af6c5ac1c3149940e  Creams, Lotions, Skin Care
# 4  b84c9f6fc53da0c6921147063d894703                   Hair Care
#
#                                        product title  \
# 0             B Natural Dakshin Pink Guava  (750 ml)
# 1           Parle Melody Chocolaty Toffee  (195.5 g)
# 2     Whiskas Adult (+1 year) Fish 3 kg Dry Cat Food
# 3  Enchanteur Romantic Perfumed Body Lotion  (250...
# 4        Pantene Hair Fall Control Shampoo  (180 ml)
#
#                                  Product Description       Brand  \
# 0  Dal contains high levels of fibers and carbohy...   B Natural
# 1  Dal contains high levels of fibers and carbohy...       Parle
# ...

# %%
Stock = [True,False]

# %%
for i in range(len(Products)):
    Products.loc[i,'Stock Availibility'] = np.random.choice(Stock,p=(0.9,0.1))

# %%
Products.head()
# Out:
#                          product_id                    category  \
# 0  0633d9fd9a3271730fae687f105c7a3a                      Juices
# 1  8687c5317c6629f89fe62e0233563246         Chocolates & Sweets
# 2  cf7eeba428641c14e43aa18ada1b5491     Household Care|Pet Food
# 3  9eb4d8359a3cbe7af6c5ac1c3149940e  Creams, Lotions, Skin Care
# 4  b84c9f6fc53da0c6921147063d894703                   Hair Care
#
#                                        product title  \
# 0             B Natural Dakshin Pink Guava  (750 ml)
# 1           Parle Melody Chocolaty Toffee  (195.5 g)
# 2     Whiskas Adult (+1 year) Fish 3 kg Dry Cat Food
# 3  Enchanteur Romantic Perfumed Body Lotion  (250...
# 4        Pantene Hair Fall Control Shampoo  (180 ml)
#
#                                  Product Description       Brand  \
# 0  Dal contains high levels of fibers and carbohy...   B Natural
# 1  Dal contains high levels of fibers and carbohy...       Parle
# ...

# %%
Products.to_csv("ProductsNew.csv")

# %%
for i in range(len(Products)):
    print(type(Products.loc[i,'product_id']))
    print(type(Products.loc[i,'category']))
    print(type(Products.loc[i,'product title']))
    print(type(Products.loc[i,'Brand']))
    print(type(Products.loc[i,'Quantity Or Pack Size']))
    print(type(Products.loc[i,'Mrp']))
    print(type(Products.loc[i,'Price']))
    print(type(Products.loc[i,'Stock Availibility']))
    print('============')
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'numpy.bool_'>
# ...
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'numpy.bool_'>
# ...
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'numpy.bool_'>
# ...
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'numpy.bool_'>
# ...
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'numpy.bool_'>
# ...
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'numpy.bool_'>
# ...
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'numpy.bool_'>
# ...
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
for i in range(len(Products)):
    Products.loc[i,'Mrp'] =  int(Products.loc[i,'Mrp'].replace(',',''))
    Products.loc[i,'Price'] =  int(Products.loc[i,'Price'].replace(',',''))

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 Products['Mrp'] = Products['Mrp'].astype(int)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
Products.to_csv("ProductsNew.csv")
